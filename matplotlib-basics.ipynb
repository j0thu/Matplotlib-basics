# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
x=np.arange(0,10)
y=np.arange(0,10)

# %% [markdown]
# # **Scatter Plot**

# %%
plt.scatter(x,y, c='g')

# %% [markdown]
# # **Adding Labels and Title**

# %%
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Scatter Plot')
plt.scatter(x,y,c='b')

# %% [markdown]
# **Saving the graph as png**

# %%
plt.savefig('filename.png')

# %% [markdown]
# # **PLOT**

# %%
y = x*x
plt.plot(x,y)

# %% [markdown]
# **Line Formatting**

# %%
plt.plot(x,y, 'r--')
plt.plot(x,y, 'r*')

# %% [markdown]
# # **SUBPLOT**
# Many plots within a given area
#
# **Parameters:** No.of Rows, No.of cols, position

# %%
plt.subplot(2,2, 1)
plt.plot(x,y,'r--')
plt.subplot(2,2, 2)
plt.plot(x,y, 'g')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')

# %% [markdown]
# **Sine and Cos waves**

# %%
x=np.arange(0, 5*np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)
plt.subplot(2,1,1)
plt.tight_layout(pad=3.0) 
plt.plot(x,y_sin)
plt.title('Sine')
plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('Cos')
# Out:
# Text(0.5, 1.0, 'Cos')

# %% [markdown]
# # **BAR PLOT**

# %%
x=[2,9,10]
y=[11,16,9]
x1=[3,9,11]
y1=[6,15,7]
plt.bar(x,y)
plt.bar(x1,y1, color='g')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # **HISTOGRAM**

# %%
a=np.array([22,12,23,34,56,67,54,34,32,12])
plt.hist(a)
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %% [markdown]
# # **PIE CHART**

# %%
labels='Python', 'C++', 'Ruby','Java'
sizes = [215, 120, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral','lightskyblue']
explode=(0.2,0,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, shadow=True, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f10b71a5150>,
#   <matplotlib.patches.Wedge at 0x7f10b71a5c10>,
#   <matplotlib.patches.Wedge at 0x7f10b71b27d0>,
#   <matplotlib.patches.Wedge at 0x7f10b71bf450>],
#  [Text(0.8530935089280713, 0.9809339758744167, 'Python'),
#   Text(-0.6359011156790025, 0.8975688113332593, 'C++'),
#   Text(-0.9668727869923487, -0.5245541094812323, 'Ruby'),
#   Text(0.7382081610145156, -0.8155051876055524, 'Java')],
#  [Text(0.5249806208788131, 0.6036516774611795, '27.2%'),
#   Text(-0.3468551540067286, 0.48958298799995953, '15.2%'),
#   Text(-0.527385156541281, -0.2861204233533994, '31.0%'),
#   Text(0.40265899691700846, -0.44482101142121033, '26.6%')])
